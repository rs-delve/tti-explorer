# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from tti_explorer import utils

plt.rcParams.update({"figure.figsize": (12, 8)})

# %%
basedir = os.path.join(os.environ['DATA'], "tti-explorer", 'test-old-new')

# %% [markdown]
# ## Test cases are the same

# %%
old_cases, old_meta = utils.load_cases(os.path.join(basedir, "new", "delve_seed0.json"))
new_cases, new_meta = utils.load_cases(os.path.join(basedir, "new-rng", "delve_seed0.json"))
# old_cases, old_meta = utils.load_cases(os.path.join(basedir, "old", "oxteam_seed0.json"))

# %%
def assert_contacts_equal(a, b):
    assert a.n_daily == b.n_daily
    for attr in ['home', 'work', 'other']:
        np.testing.assert_array_equal(getattr(a, attr), getattr(b, attr))

# %%
for (old_case, old_contacts), (new_case, new_contacts) in zip(old_cases, new_cases):
    assert old_case == new_case
    assert_contacts_equal(old_contacts, new_contacts)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-27-cefe9ea7bd0d> in <module>
#       1 for (old_case, old_contacts), (new_case, new_contacts) in zip(old_cases, new_cases):
# ----> 2     assert old_case == new_case
#       3     assert_contacts_equal(old_contacts, new_contacts)
#
# AssertionError:

# %%
def population_stats(case_contacts):
    case_outputs = list()
    for case, contacts in case_contacts:
        case_outputs.append(
            dict(
                under18=case.under18,
                covid=case.covid,
                symptomatic=case.symptomatic,
                day_noticed_symptoms=case.day_noticed_symptoms
            )
        )
    return pd.DataFrame(case_outputs), _

# %%
old_case_stats, _ = population_stats(old_cases)
new_case_stats, _ = population_stats(new_cases)

# %% [markdown]
# ## Compare case statistics

# %% [markdown]
# Number of cases with certain properties

# %%
histogram = pd.concat(
    {
        "Old": old_case_stats.drop('day_noticed_symptoms', 1).sum(),
        "New": new_case_stats.drop('day_noticed_symptoms', 1).sum()
    },
    axis=1
)

histogram['Difference'] = histogram.diff(axis=1).dropna(axis=1)
histogram[f'Difference as % of total ({len(old_case_stats)/1000:.0f}k)'] = (
    histogram['Difference'] / len(old_case_stats)
).apply(
    lambda x: f"{100*x:.2f}%"
)

histogram
# Out:
#                Old    New  Difference Difference as % of total (100k)
# under18      20852  20948        96.0                           0.10%
# covid        16473  16447       -26.0                          -0.03%
# symptomatic  93550  93366      -184.0                          -0.18%

# %%
histogram = pd.concat({
    "Old": old_case_stats['day_noticed_symptoms'].value_counts(),
    "New": new_case_stats['day_noticed_symptoms'].value_counts()
    },
    axis=1
)

histogram['Difference'] = histogram.diff(axis=1).dropna(axis=1)
histogram[f'Difference as % of total ({len(old_case_stats)/1000:.0f}k)'] = (
    histogram['Difference'] / len(old_case_stats)
).apply(
    lambda x: f"{100*x:.2f}%"
)
histogram
# Out:
#       Old    New  Difference Difference as % of total (100k)
# -1   6450   6634       184.0                           0.18%
#  1  23675  23203      -472.0                          -0.47%
#  2  23256  23281        25.0                           0.03%
#  3  18812  18821         9.0                           0.01%
#  4   9349   9320       -29.0                          -0.03%
#  5   4660   4789       129.0                           0.13%
#  6   4709   4639       -70.0                          -0.07%
#  7   4542   4678       136.0                           0.14%
#  8   4547   4635        88.0                           0.09%

# %% [markdown]
# ## Test results are the same

# %%
new_res_dir = os.path.join(basedir, "new", "results")
old_res_dir = os.path.join(basedir, "old", "results")

# %%
assert os.listdir(new_res_dir) == os.listdir(new_res_dir)

# %%
new_all_res = pd.read_csv(os.path.join(new_res_dir, "all_results.csv"), index_col=0).drop('case_file', axis=1)
old_all_res = pd.read_csv(os.path.join(old_res_dir, "all_results.csv"), index_col=0).drop('case_file', axis=1)

# %%
new_means = new_all_res.query("statistic=='mean'").drop('statistic', axis=1)
new_stds = new_all_res.query("statistic=='std'").drop('statistic', axis=1)
old_means = old_all_res.query("statistic=='mean'").drop('statistic', axis=1)
old_stds = old_all_res.query("statistic=='std'").drop('statistic', axis=1)

# %%
delta = (new_means - old_means)
delta_stds = (new_stds - old_stds)

# %%
pd.testing.assert_frame_equal(new_all_res, old_all_res)

# %%
delta
# Out:
#                                    Base R  Effective R  # Manual Traces  \
# scenario
# S5_no_TTI                             0.0          0.0              0.0
# S5_symptom_based_TTI                  0.0          0.0              0.0
# S5_test_based_TTI                     0.0          0.0              0.0
# S5_test_based_TTI_test_contacts       0.0          0.0              0.0
# S4_no_TTI                             0.0          0.0              0.0
# S4_symptom_based_TTI                  0.0          0.0              0.0
# S4_test_based_TTI                     0.0          0.0              0.0
# S4_test_based_TTI_test_contacts       0.0          0.0              0.0
# S3_no_TTI                             0.0          0.0              0.0
# S3_symptom_based_TTI                  0.0          0.0              0.0
# S3_test_based_TTI                     0.0          0.0              0.0
# S3_test_based_TTI_test_contacts       0.0          0.0              0.0
# S2_no_TTI                             0.0          0.0              0.0
# S2_symptom_based_TTI                  0.0          0.0              0.0
# S2_test_based_TTI                     0.0          0.0              0.0
# S2_test_based_TTI_test_contacts       0.0          0.0              0.0
# S1_no_TTI                             0.0          0.0              0.0
# S1_symptom_based_TTI                  0.0          0.0              0.0
# S1_test_based_TTI                     0.0          0.0              0.0
# S1_test_based_TTI_test_contacts       0.0          0.0              0.0
# S0                                    0.0          0.0              0.0
# S5_test_based_TTI_full_compliance     0.0          0.0              0.0
# S4_test_based_TTI_full_compliance     0.0          0.0              0.0
# S3_test_based_TTI_full_compliance     0.0          0.0              0.0
# S2_test_based_TTI_full_compliance     0.0          0.0              0.0
# S1_test_based_TTI_full_compliance     0.0          0.0              0.0
#
#                                    # App Traces  # Tests Needed  \
# scenario
# S5_no_TTI                                   0.0             0.0
# S5_symptom_based_TTI                        0.0             0.0
# S5_test_based_TTI                           0.0             0.0
# S5_test_based_TTI_test_contacts             0.0             0.0
# S4_no_TTI                                   0.0             0.0
# S4_symptom_based_TTI                        0.0             0.0
# S4_test_based_TTI                           0.0             0.0
# S4_test_based_TTI_test_contacts             0.0             0.0
# S3_no_TTI                                   0.0             0.0
# S3_symptom_based_TTI                        0.0             0.0
# S3_test_based_TTI                           0.0             0.0
# S3_test_based_TTI_test_contacts             0.0             0.0
# S2_no_TTI                                   0.0             0.0
# S2_symptom_based_TTI                        0.0             0.0
# S2_test_based_TTI                           0.0             0.0
# S2_test_based_TTI_test_contacts             0.0             0.0
# S1_no_TTI                                   0.0             0.0
# S1_symptom_based_TTI                        0.0             0.0
# S1_test_based_TTI                           0.0             0.0
# S1_test_based_TTI_test_contacts             0.0             0.0
# S0                                          0.0             0.0
# S5_test_based_TTI_full_compliance           0.0             0.0
# S4_test_based_TTI_full_compliance           0.0             0.0
# S3_test_based_TTI_full_compliance           0.0             0.0
# S2_test_based_TTI_full_compliance           0.0             0.0
# S1_test_based_TTI_full_compliance           0.0             0.0
#
#                                    # PersonDays Quarantined  \
# scenario
# S5_no_TTI                                               0.0
# S5_symptom_based_TTI                                    0.0
# S5_test_based_TTI                                       0.0
# S5_test_based_TTI_test_contacts                         0.0
# S4_no_TTI                                               0.0
# S4_symptom_based_TTI                                    0.0
# S4_test_based_TTI                                       0.0
# S4_test_based_TTI_test_contacts                         0.0
# S3_no_TTI                                               0.0
# S3_symptom_based_TTI                                    0.0
# S3_test_based_TTI                                       0.0
# S3_test_based_TTI_test_contacts                         0.0
# S2_no_TTI                                               0.0
# S2_symptom_based_TTI                                    0.0
# S2_test_based_TTI                                       0.0
# S2_test_based_TTI_test_contacts                         0.0
# S1_no_TTI                                               0.0
# S1_symptom_based_TTI                                    0.0
# S1_test_based_TTI                                       0.0
# S1_test_based_TTI_test_contacts                         0.0
# S0                                                      0.0
# S5_test_based_TTI_full_compliance                       0.0
# S4_test_based_TTI_full_compliance                       0.0
# S3_test_based_TTI_full_compliance                       0.0
# S2_test_based_TTI_full_compliance                       0.0
# S1_test_based_TTI_full_compliance                       0.0
#
#                                    % of Ongoing Transmission Prevented by Social Distancing  \
# scenario
# S5_no_TTI                                                                        0.0
# S5_symptom_based_TTI                                                             0.0
# S5_test_based_TTI                                                                0.0
# S5_test_based_TTI_test_contacts                                                  0.0
# S4_no_TTI                                                                        0.0
# S4_symptom_based_TTI                                                             0.0
# S4_test_based_TTI                                                                0.0
# S4_test_based_TTI_test_contacts                                                  0.0
# S3_no_TTI                                                                        0.0
# S3_symptom_based_TTI                                                             0.0
# S3_test_based_TTI                                                                0.0
# S3_test_based_TTI_test_contacts                                                  0.0
# S2_no_TTI                                                                        0.0
# S2_symptom_based_TTI                                                             0.0
# S2_test_based_TTI                                                                0.0
# S2_test_based_TTI_test_contacts                                                  0.0
# S1_no_TTI                                                                        0.0
# S1_symptom_based_TTI                                                             0.0
# S1_test_based_TTI                                                                0.0
# S1_test_based_TTI_test_contacts                                                  0.0
# S0                                                                               0.0
# S5_test_based_TTI_full_compliance                                                0.0
# S4_test_based_TTI_full_compliance                                                0.0
# S3_test_based_TTI_full_compliance                                                0.0
# S2_test_based_TTI_full_compliance                                                0.0
# S1_test_based_TTI_full_compliance                                                0.0
#
#                                    % of Ongoing Transmission Prevented by Isolating Cases with Symptoms and Quarantining Households  \
# scenario
# S5_no_TTI                                                                        0.0
# S5_symptom_based_TTI                                                             0.0
# S5_test_based_TTI                                                                0.0
# S5_test_based_TTI_test_contacts                                                  0.0
# S4_no_TTI                                                                        0.0
# S4_symptom_based_TTI                                                             0.0
# S4_test_based_TTI                                                                0.0
# S4_test_based_TTI_test_contacts                                                  0.0
# S3_no_TTI                                                                        0.0
# S3_symptom_based_TTI                                                             0.0
# S3_test_based_TTI                                                                0.0
# S3_test_based_TTI_test_contacts                                                  0.0
# S2_no_TTI                                                                        0.0
# S2_symptom_based_TTI                                                             0.0
# S2_test_based_TTI                                                                0.0
# S2_test_based_TTI_test_contacts                                                  0.0
# S1_no_TTI                                                                        0.0
# S1_symptom_based_TTI                                                             0.0
# S1_test_based_TTI                                                                0.0
# S1_test_based_TTI_test_contacts                                                  0.0
# S0                                                                               0.0
# S5_test_based_TTI_full_compliance                                                0.0
# S4_test_based_TTI_full_compliance                                                0.0
# S3_test_based_TTI_full_compliance                                                0.0
# S2_test_based_TTI_full_compliance                                                0.0
# S1_test_based_TTI_full_compliance                                                0.0
#
#                                    % of Ongoing Transmission Prevented by Tracing  \
# scenario
# S5_no_TTI                                                                     0.0
# S5_symptom_based_TTI                                                          0.0
# S5_test_based_TTI                                                             0.0
# S5_test_based_TTI_test_contacts                                               0.0
# S4_no_TTI                                                                     0.0
# S4_symptom_based_TTI                                                          0.0
# S4_test_based_TTI                                                             0.0
# S4_test_based_TTI_test_contacts                                               0.0
# S3_no_TTI                                                                     0.0
# S3_symptom_based_TTI                                                          0.0
# S3_test_based_TTI                                                             0.0
# S3_test_based_TTI_test_contacts                                               0.0
# S2_no_TTI                                                                     0.0
# S2_symptom_based_TTI                                                          0.0
# S2_test_based_TTI                                                             0.0
# S2_test_based_TTI_test_contacts                                               0.0
# S1_no_TTI                                                                     0.0
# S1_symptom_based_TTI                                                          0.0
# S1_test_based_TTI                                                             0.0
# S1_test_based_TTI_test_contacts                                               0.0
# S0                                                                            0.0
# S5_test_based_TTI_full_compliance                                             0.0
# S4_test_based_TTI_full_compliance                                             0.0
# S3_test_based_TTI_full_compliance                                             0.0
# S2_test_based_TTI_full_compliance                                             0.0
# S1_test_based_TTI_full_compliance                                             0.0
#
#                                    % of Ongoing Transmission Allowed Through by Asymptomatic Cases Not Being Caught  \
# scenario
# S5_no_TTI                                                                        0.0
# S5_symptom_based_TTI                                                             0.0
# S5_test_based_TTI                                                                0.0
# S5_test_based_TTI_test_contacts                                                  0.0
# S4_no_TTI                                                                        0.0
# S4_symptom_based_TTI                                                             0.0
# S4_test_based_TTI                                                                0.0
# S4_test_based_TTI_test_contacts                                                  0.0
# S3_no_TTI                                                                        0.0
# S3_symptom_based_TTI                                                             0.0
# S3_test_based_TTI                                                                0.0
# S3_test_based_TTI_test_contacts                                                  0.0
# S2_no_TTI                                                                        0.0
# S2_symptom_based_TTI                                                             0.0
# S2_test_based_TTI                                                                0.0
# S2_test_based_TTI_test_contacts                                                  0.0
# S1_no_TTI                                                                        0.0
# S1_symptom_based_TTI                                                             0.0
# S1_test_based_TTI                                                                0.0
# S1_test_based_TTI_test_contacts                                                  0.0
# S0                                                                               0.0
# S5_test_based_TTI_full_compliance                                                0.0
# S4_test_based_TTI_full_compliance                                                0.0
# S3_test_based_TTI_full_compliance                                                0.0
# S2_test_based_TTI_full_compliance                                                0.0
# S1_test_based_TTI_full_compliance                                                0.0
#
#                                    % of Ongoing Transmission Allowed Through by Symptomatic Cases Not Complying  \
# scenario
# S5_no_TTI                                                                        0.0
# S5_symptom_based_TTI                                                             0.0
# S5_test_based_TTI                                                                0.0
# S5_test_based_TTI_test_contacts                                                  0.0
# S4_no_TTI                                                                        0.0
# S4_symptom_based_TTI                                                             0.0
# S4_test_based_TTI                                                                0.0
# S4_test_based_TTI_test_contacts                                                  0.0
# S3_no_TTI                                                                        0.0
# S3_symptom_based_TTI                                                             0.0
# S3_test_based_TTI                                                                0.0
# S3_test_based_TTI_test_contacts                                                  0.0
# S2_no_TTI                                                                        0.0
# S2_symptom_based_TTI                                                             0.0
# S2_test_based_TTI                                                                0.0
# S2_test_based_TTI_test_contacts                                                  0.0
# S1_no_TTI                                                                        0.0
# S1_symptom_based_TTI                                                             0.0
# S1_test_based_TTI                                                                0.0
# S1_test_based_TTI_test_contacts                                                  0.0
# S0                                                                               0.0
# S5_test_based_TTI_full_compliance                                                0.0
# S4_test_based_TTI_full_compliance                                                0.0
# S3_test_based_TTI_full_compliance                                                0.0
# S2_test_based_TTI_full_compliance                                                0.0
# S1_test_based_TTI_full_compliance                                                0.0
#
#                                    % of Ongoing Transmission Allowed Through by TTI Policy  \
# scenario
# S5_no_TTI                                                                        0.0
# S5_symptom_based_TTI                                                             0.0
# S5_test_based_TTI                                                                0.0
# S5_test_based_TTI_test_contacts                                                  0.0
# S4_no_TTI                                                                        0.0
# S4_symptom_based_TTI                                                             0.0
# S4_test_based_TTI                                                                0.0
# S4_test_based_TTI_test_contacts                                                  0.0
# S3_no_TTI                                                                        0.0
# S3_symptom_based_TTI                                                             0.0
# S3_test_based_TTI                                                                0.0
# S3_test_based_TTI_test_contacts                                                  0.0
# S2_no_TTI                                                                        0.0
# S2_symptom_based_TTI                                                             0.0
# S2_test_based_TTI                                                                0.0
# S2_test_based_TTI_test_contacts                                                  0.0
# S1_no_TTI                                                                        0.0
# S1_symptom_based_TTI                                                             0.0
# S1_test_based_TTI                                                                0.0
# S1_test_based_TTI_test_contacts                                                  0.0
# S0                                                                               0.0
# S5_test_based_TTI_full_compliance                                                0.0
# S4_test_based_TTI_full_compliance                                                0.0
# S3_test_based_TTI_full_compliance                                                0.0
# S2_test_based_TTI_full_compliance                                                0.0
# S1_test_based_TTI_full_compliance                                                0.0
#
#                                    % of Ongoing Transmission Prevented by Social Distancing - Symptomatic Compliant Only
# scenario
# S5_no_TTI                                                                        0.0
# S5_symptom_based_TTI                                                             0.0
# S5_test_based_TTI                                                                0.0
# S5_test_based_TTI_test_contacts                                                  0.0
# S4_no_TTI                                                                        0.0
# S4_symptom_based_TTI                                                             0.0
# S4_test_based_TTI                                                                0.0
# S4_test_based_TTI_test_contacts                                                  0.0
# S3_no_TTI                                                                        0.0
# S3_symptom_based_TTI                                                             0.0
# S3_test_based_TTI                                                                0.0
# S3_test_based_TTI_test_contacts                                                  0.0
# S2_no_TTI                                                                        0.0
# S2_symptom_based_TTI                                                             0.0
# S2_test_based_TTI                                                                0.0
# S2_test_based_TTI_test_contacts                                                  0.0
# S1_no_TTI                                                                        0.0
# S1_symptom_based_TTI                                                             0.0
# S1_test_based_TTI                                                                0.0
# S1_test_based_TTI_test_contacts                                                  0.0
# S0                                                                               0.0
# S5_test_based_TTI_full_compliance                                                0.0
# S4_test_based_TTI_full_compliance                                                0.0
# S3_test_based_TTI_full_compliance                                                0.0
# S2_test_based_TTI_full_compliance                                                0.0
# S1_test_based_TTI_full_compliance                                                0.0

# %%
from tti_explorer.utils import bool_bernoulli

# %%
import numpy as np
rs = np.random.RandomState(0)

# %%
p = 0.65

# %%
rs = np.random.RandomState(0)
sample = rs.uniform(size=100000) < p

# %%
rs = np.random.RandomState(0)
sample2 = np.array([bool_bernoulli(p, rs) for _ in range(100000)])

# %%
sample.mean()
# Out:
# 0.65051

# %%
sample2.mean()
# Out:
# 0.65051
